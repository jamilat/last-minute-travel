# %%
import random
import pandas as pd

pd.set_option('display.max_rows', 100)

# %%
data_path = "../data/CanadaCamp.csv"
data_path_mod = "../data/CanadaCamp_utf.csv"

# %%
with open(data_path, "rb") as f:
    lines = [l.decode('utf8', 'ignore') for l in f.readlines()]

with open(data_path_mod, "w") as f:
    for line in lines:
        f.write(line)

# %%
data = pd.read_csv(data_path_mod, encoding="utf-8")

# %%
data.info()

# %%
data.head()

# %%
data

# %%
val_cts = pd.DataFrame(data["ODRSF_facility_type"].value_counts())

# %%
val_cts

# %%
["trail", "*park*", "soccer", "swimming"]

# %%
val_cts[val_cts["Source_Facility_Type"] > 100]

# %%
import random
import pandas as pd

pd.set_option('display.max_rows', 100)

# %%
city_dict = {
    "Alberta": [
        "Banff",
        "Brooks",
        "Calgary",
        "Edmonton",
        "Fort McMurray",
        "Grande Prairie",
        "Jasper",
        "Lake Louise",
        "Lethbridge",
        "Medicine Hat",
        "Red Deer",
        "Saint Albert"
    ],
    "British Columbia": [
        "Barkerville",
        "Burnaby",
        "Campbell River",
        "Chilliwack",
        "Courtenay",
        "Cranbrook",
        "Dawson Creek",
        "Delta",
        "Esquimalt",
        "Fort Saint James",
        "Fort Saint John",
        "Hope",
        "Kamloops",
        "Kelowna",
        "Kimberley",
        "Kitimat",
        "Langley",
        "Nanaimo",
        "Nelson",
        "New Westminster",
        "North Vancouver",
        "Oak Bay",
        "Penticton",
        "Powell River",
        "Prince George",
        "Prince Rupert",
        "Quesnel",
        "Revelstoke",
        "Rossland",
        "Trail",
        "Vancouver",
        "Vernon",
        "Victoria",
        "West Vancouver",
        "White Rock"
    ],
    "Manitoba": [
        "Brandon",
        "Churchill",
        "Dauphin",
        "Flin Flon",
        "Kildonan",
        "Saint Boniface",
        "Swan River",
        "Thompson",
        "Winnipeg",
        "York Factory"
    ],
    "New Brunswick": [
        "Bathurst",
        "Caraquet",
        "Dalhousie",
        "Fredericton",
        "Miramichi",
        "Moncton",
        "Saint John"
    ],
    "Newfoundland and Labrador": [
        "Argentia",
        "Bonavista",
        "Channel-Port aux Basques",
        "Corner Brook",
        "Ferryland",
        "Gander",
        "Grand Falls–Windsor",
        "Happy Valley–Goose Bay",
        "Harbour Grace",
        "Labrador City",
        "Placentia",
        "Saint Anthony",
        "St. John's",
        "Wabana"
    ],
    "Northwest Territories": [
        "Fort Smith",
        "Hay River",
        "Inuvik",
        "Tuktoyaktuk",
        "Yellowknife",
    ],
    "Nova Scotia": [
        "Baddeck",
        "Digby",
        "Glace Bay",
        "Halifax",
        "Liverpool",
        "Louisbourg",
        "Lunenburg",
        "Pictou",
        "Port Hawkesbury",
        "Springhill",
        "Sydney",
        "Yarmouth"
    ],
    "Nunavut": [
        "Iqaluit"
    ],
    "Ontario": [
        "Bancroft",
        "Barrie",
        "Belleville",
        "Brampton",
        "Brantford",
        "Brockville",
        "Burlington",
        "Cambridge",
        "Chatham",
        "Chatham-Kent",
        "Cornwall",
        "Elliot Lake",
        "Etobicoke",
        "Fort Erie",
        "Fort Frances",
        "Gananoque",
        "Guelph",
        "Hamilton",
        "Iroquois Falls",
        "Kapuskasing",
        "Kawartha Lakes",
        "Kenora",
        "Kingston",
        "Kirkland Lake",
        "Kitchener",
        "Laurentian Hills",
        "London",
        "Midland",
        "Mississauga",
        "Moose Factory",
        "Moosonee",
        "Niagara Falls",
        "Niagara-on-the-Lake",
        "North Bay",
        "North York",
        "Oakville",
        "Orillia",
        "Oshawa",
        "Ottawa",
        "Parry Sound",
        "Perth",
        "Peterborough",
        "Picton",
        "Port Colborne",
        "Saint Catharines",
        "Saint Thomas",
        "Sarnia-Clearwater",
        "Sault Sainte Marie",
        "Scarborough",
        "Simcoe",
        "Stratford",
        "Sudbury",
        "Temiskaming Shores",
        "Thorold",
        "Thunder Bay",
        "Timmins",
        "Toronto",
        "Trenton",
        "Waterloo",
        "Welland",
        "West Nipissing",
        "Windsor",
        "Woodstock",
        "York"
    ],
    "Prince Edward Island": [
        "Borden",
        "Cavendish",
        "Charlottetown",
        "Souris",
        "Summerside"
    ],
    "Quebec": [
        "Asbestos",
        "Baie-Comeau",
        "Beloeil",
        "Cap-de-la-Madeleine",
        "Chambly",
        "Charlesbourg",
        "Châteauguay",
        "Chibougamau",
        "Côte-Saint-Luc",
        "Dorval",
        "Gaspé",
        "Gatineau",
        "Granby",
        "Havre-Saint-Pierre",
        "Hull",
        "Jonquière",
        "Kuujjuaq",
        "La Salle",
        "La Tuque",
        "Lachine",
        "Laval",
        "Lévis",
        "Longueuil",
        "Magog",
        "Matane",
        "Montreal",
        "Montréal-Nord",
        "Percé",
        "Port-Cartier",
        "Quebec",
        "Rimouski",
        "Rouyn-Noranda",
        "Saguenay",
        "Saint-Eustache",
        "Saint-Hubert",
        "Sainte-Anne-de-Beaupré",
        "Sainte-Foy",
        "Sainte-Thérèse",
        "Sept-Îles",
        "Sherbrooke",
        "Sorel-Tracy",
        "Trois-Rivières",
        "Val-d’Or",
        "Waskaganish"
    ],
    "Saskatchewan": [
        "Batoche",
        "Cumberland House",
        "Estevan",
        "Flin Flon",
        "Moose Jaw",
        "Prince Albert",
        "Regina",
        "Saskatoon",
        "Uranium City"
    ],
    "Yukon": [
        "Dawson",
        "Watson Lake",
        "Whitehorse"
    ]
}

# %%
activities_dict = {
    "Swimming": [
        "RONA Coquitlam (Austin)",
        "Kensington Park Outdoor Pool",
        "Eileen Dailly Leisure Pool & Fitness Centre",
        "C.G. Brown Memorial Pool",
        "Renfrew Park Pool",
        "Templeton Park Pool",
        "MacPherson Outdoor Pool",
        "Central Park Outdoor Pool",
        "SFU Aquatic Centre",
        "City Centre Aquatic Complex",
        "Killarney Pool",
        "Propel Swimming Lessons Burnaby",
        "Wading Pool",
        "Garden Grove Dr",
        "Kerrisdale Pool",
        "Blue Mountain Wading Pool",
        "Port Coquitlam Leisure Pool",
        "Lord Byng Pool & Fitness Centre",
        "Vancouver Aquatic Centre",
        "Second Beach Swimming Pool",
        "Stan Stronge Pool"
    ],
    "River Rafting": [
        "Triad River Tours",
        "Squamish Rafting Company",
        "Canadian Outback Rafting",
        "Chilliwack River Rafting",
        "Wedge Rafting",
        "Alpine Adventures",
        "West Coast Canyoning Adventures",
        "Orion River Rafting",
        "Outdoor Adventure Center",
        "Osprey Rafting Company",
        "Kumsheen Rafting Resort",
        "Adams River Rafting Ltd",
        "River Drifters - White Salmon River Rafting",
        "Wet Planet Rafting and Kayaking",
        "Interior Whitewater Expeditions Ltd",
        "Northern Rockies Adventures",
        "Pangaea River Rafting | Missoula Whitewater Rafting",
        "Winding Waters River Expeditions",
        "Glacier Guides and Montana Raft",
        "Hydra River Guides"
    ],
    "Cherry Blossom Viewing": [
        "Cherry Blossom Avenue",
        "Cherry Blossom Garden",
        "Cherry Blossom Intersection",
        "Queen Elizabeth Park",
        "Stanley Park",
        "Sunrise Park",
        "Vanier Park",
        "Greenheart TreeWalk",
        "Salsbury Park",
        "Jean Beaty Park",
        "UBC Botanical Garden",
        "Andy Livingstone Park",
        "Nikkei National Museum & Cultural Centre",
        "Alice Townley Park",
        "John Hendry Park (Trout Lake Park)",
        "Devonian Harbour Park",
        "Minoru Park",
        "Mount Pleasant Park",
        "Prince Edward Park"
    ],
    "Picnic": [
        "Barnet Marine Park Picnic Areas",
        "Confederation Park Picnic Areas",
        "Central Park Picnic Areas",
        "Burnaby Fraser Foreshore Park Picnic Areas",
        "Belcarra Picnic Area",
        "Picnic Pavilion",
        "Mundy Park Picnic Shelter",
        "Prospect Point Picnic Area",
        "Picnic Area",
        "Locarno Beach Picnic Site",
        "Covered Area",
        "Picnic Area",
        "Rocky Point Picnic Shelter",
        "Jack`s Burn picnic area",
        "Bambi Picnic Vancouver",
        "Meunch Bar Picnic Area",
        "Picnic point",
        "Hume Park",
        "Burnaby Fraser Foreshore Park",
        "Guelph Park"
    ],
    "Beach": [
        "Maple Beach",
        "Jug Island Beach",
        "Locarno Beach",
        "Parkside Beach",
        "English Bay Beach",
        "Sunset Beach Park",
        "Second Beach",
        "Third Beach",
        "Buntzen Lake North Beach",
        "Trout Lake Beach",
        "Kitsilano Beach Park",
        "New Brighton Beach",
        "Dundarave Beach",
        "Spanish Banks Beach Park",
        "Ambleside Beach",
        "Beach denj",
        "Spanish Banks Beach",
        "Anette Beach",
        "White Pine Beach",
        "Pebbly Beach"
    ],
    "Rock Climbing": [
        "Bomber Climbing",
        "SFU Climbing Wall",
        "Outdoor Bouldering Wall",
        "Vancouver Mountain Guides",
        "Climb Base5 (Coquitlam)",
        "Clip 'n Climb Vancouver",
        "Climb Base5 (North Vancouver)",
        "The Hive Bouldering Gym",
        "Coastal Climbing Centre",
        "Project Climbing Cloverdale",
        "The Hive Heights",
        "Climblife",
        "The Hive Climbing and Fitness",
        "Thompson community bouldering",
        "Vancouver Climbers Association",
        "Canada West Mountain School",
        "The Rock Wall Climbing Gym",
        "Climb Away",
        "Project Climbing Centre",
        "Ground Up Climbing Centre"
    ],
    "Hiking/Trekking": [
        "Velodrome Trail",
        "Trans Canada Trail",
        "Drummond's Walk",
        "Burnaby Mountain Conservation Area",
        "Burnaby Mountain walking path",
        "Suraci’s Trail",
        "Burnaby Mountain Biking and Hiking Trails",
        "Burnaby Mountain Urban Trail",
        "Jug Island Trailhead",
        "Central Valley Greenway",
        "Willingdon Jogging Trail",
        "Cottonwood Trail",
        "Burnaby lake",
        "South Side Trail",
        "Southshore Trail",
        "Trail of Hope",
        "Baden Powell Trail",
        "Glenbrook Ravine Trail",
        "Burnaby Lake Regional Park",
        "West Forest Trails"
    ],
    "Camping": [
        "BCRV",
        "Muskrat Meadow Outdoor Group Campsite",
        "Anmore Camp & RV Park",
        "Raven's Nest Outdoor Group Campsite",
        "Dogwood Campgrounds & RV Park",
        "Seymour Group Campsite",
        "Campnab",
        "Campertunity",
        "Fort Camping",
        "Discover Camping",
        "Girl Guides of Canada - Woodward's Landing Campground",
        "Bishop Creek Marine Campground",
        "Capilano River RV Park",
        "British Columbia Lodging & Campgrounds Association",
        "Porteau Cove Campground",
        "Klahanie Campground",
        "Montague Provincial Campground (K2 Park Service)",
        "BC Hydro Stave Falls Lodge and Campsite",
        "Apodaca Provincial Park",
        "Rolley Lake Provincial Park"
    ],
    "Cycling": [
        "Van City Bikes and Skis",
        "Burnaby Mountain Bike Skills Facility",
        "Burnaby Velodrome Club",
        "Willingdon Linear Park",
        "Riverview Forest Biking Trails",
        "HUB Cycling",
        "Cap's Bicycle Shop",
        "Mactalla Cycles",
        "Steed Cycles",
        "Union Street Cycle",
        "Yes Cycle Bike Rental",
        "Tynehead Regional Park",
        "Kissing Crows Cyclery",
        "Great Explorations",
        "Velo Star Cafe",
        "Reckless Shipyards: eBikes, Skis & More!",
        "Cycle City Bike Shop & Repairs",
        "Bikes For All",
        "Bert Flinn Park",
        "Cap's Electric Bike Centre",
        "Coal Harbour Bike Rental"
    ],
    "Boating": [
        "BURNABY SAILING ASSOCIATION - Barnet Marine Park",
        "Cates Park Boat Ramp",
        "Burrard Civic Marina",
        "Rocky Point Public Boat Launch",
        "Mosquito Creek Marina",
        "Gord's boat",
        "2nd Launch boat",
        "Shelter Island Marina & Boatyard",
        "Cooper Boating",
        "Bayshore West Marina",
        "Quayside Marina",
        "Crescent Beach Marina",
        "Reed Point Marina",
        "Granville Island Boat Rentals",
        "Ambleside Park | West Vancouver",
        "Burnaby Fraser Foreshore Park",
        "Heather Civic Marina",
        "Westminster Pier Park",
        "Coal Harbour Marina",
        "Grant Narrows Park at Pitt–Addington Marsh Wildlife Management Area"
    ],
    "Skiing/Snowboarding": [
        "Grouse Mountain",
        "Mt Seymour Resort",
        "Cypress Mountain",
        "Grouse Mountain",
        "Whistler Blackcomb",
        "Baldy Mountain Resort",
        "Sun Peaks Resort",
        "SilverStar Mountain Resort",
        "RED Mountain Resort",
        "Whistler Blackcomb",
        "Dakota Ridge Ski Area",
        "Big White Ski Resort",
        "Mount Timothy Recreational Resort",
        "Club Intrawest",
        "Troll Ski Resort",
        "Whitecap Alpine",
        "Mount Cain Alpine Park",
        "Fortress Ski Area",
        "Purden Ski Village",
        "Phoenix Mountain Ski Area",
        "Revelstoke Mountain Resort"
    ],
    "Fishing": [
        "ABF Charters/ Guided Sportfishing/Gibsons BC",
        "Fraser Fishing Adventures",
        "John Hendry Park (Trout Lake Park)",
        "Deer Lake Park",
        "Silversides Fishing Adventures",
        "Burnaby Lake Regional Park",
        "Cleveland Dam",
        "Whytecliff Park | West Vancouver",
        "Cabin Lake",
        "Burnaby Fraser Foreshore Park",
        "Fraser River Park",
        "Fishing dock",
        "Rocky Point Park",
        "Capilano River Hatchery",
        "Lang's Fishing Adventures",
        "CRAB Park",
        "Stave River",
        "Westminster Pier Park",
        "Rolley Lake Provincial Park",
        "Lower Pond",
        "Kanaka Creek Regional Park",
        "Lost Lagoon, Stanley Park"
    ],
    "Horse-riding": [
        "Leghorn Ranch Horseback Trail Rides",
        "Leghorn Ranch Horseback Trail Rides",
        "Hidden Trails Ltd",
        "Glen Valley Stables",
        "Footnote Farm",
        "Trail Riders of the Canadian Rockies",
        "Southlands Heritage Farm",
        "North Shore Equestrian Centre",
        "Sun Hills Riding Centre",
        "Copper Cayuse Outfitters",
        "Farm Ventures",
        "Banff Trail Riders - Stables",
        "Valle Vista Stables",
        "Inspire horsemanship",
        "A/Z Mountain Adventures",
        "Conestogo River Horseback Adventures",
        "Boundary Ranch",
        "Saddle Peak Trail Rides",
        "Pacific Riding for Developing Abilities",
        "Pathways on Pleasure Valley",
        "Carousel Canada Equine Riding Centre"
    ],
    "Canoeing": [
        "Northshore Kayaking",
        "Creekside Kayaks at Dragon Boat BC",
        "Gulf Island Kayaking",
        "Pedals & Paddles",
        "Tofino Sea Kayaking",
        "Talaysay Tours",
        "Majestic Ocean Kayaking",
        "North Island Kayak",
        "Spirit of the West Adventures",
        "Banff Canoe Club",
        "Skyview Outdoors",
        "Northern Rockies Adventures",
        "Seaward Kayaks",
        "Bowron Lake Provincial Park",
        "Say Nuth Khaw Yum Provincial Park",
        "Whytecliff Park | West Vancouver",
        "Vancouver Seawall",
        "Kanaka Creek Regional Park",
        "Wildcoast Adventures",
        "Grant Narrows Park at Pitt–Addington Marsh Wildlife Management Area"
    ],
    "Mountaineering": [
        "Grouse Grind Trail",
        "Cabin Lake",
        "Kennedy Falls",
        "Vancouver Mountain Guides",
        "Capilano Suspension Bridge Park",
        "Whytecliff Park | West Vancouver",
        "Stanley Park",
        "Woodland Falls",
        "Say Nuth Khaw Yum Provincial Park",
        "Crown Mountain",
        "Pinecone Burke Provincial Park",
        "Ammonite Falls",
        "Panorama Ridge",
        "Watersprite Lake",
        "Mt Thom Park",
        "Hiking trails & scenic valley views",
        "Vancouver Mountain Guides",
        "West Lion",
        "Cheam Peak",
        "Mount Arrowsmith",
        "Rocky Mountaineer Station"
    ],
    "Photography": [
        "Vancouver Photographer | Enjoy The Journey Studios",
        "Digital Orca",
        "Stanley Park",
        "FlyOver Canada",
        "Inukshuk",
        "Queen Elizabeth Park",
        "Capilano Suspension Bridge Park",
        "Equinox Gallery",
        "Canada Place",
        "VanDusen Botanical Garden",
        "Kennedy Falls",
        "Museum of Archaeology & Ethnology",
        "Guelph Park",
        "Gastown Steam Clock",
        "Olympic Cauldron",
        "Lighthouse Park | West Vancouver",
        "Rocky Point Park",
        "Prospect Point Lookout",
        "Sunset Beach Park",
        "Creekside Park",
        "Bloedel Conservatory"
    ]
}

# %%
# df_cities = pd.DataFrame(columns=["city", "province", "activity"])

# for province, list_city in city_dict.items():
#     for city in list_city:
#         df_cities.loc[len(df_cities)] = [city, province, random.sample(list(activities_dict.keys()), random.sample([3, 4, 5, 6], 1)[0])]

# %%
# df_cities.to_csv("../data/city_activity.csv", index=0)

# %%
# df_activities = pd.DataFrame(columns=["activity", "spots"])

# for activity, list_spots in activities_dict.items():
#     df_activities.loc[len(df_activities)] = [activity, random.sample(list_spots, random.sample(list(range(2, 10)), 1)[0])]

# %%
# df_activities.to_csv("../data/activity_spots.csv", index=0)

# %%
df_cities_activities_spots = pd.DataFrame(columns=["city", "province", "activity", "spots"])

for province, list_city in city_dict.items():
    for city in list_city:
        for activity in random.sample(list(activities_dict.keys()), random.sample([3, 4, 5, 6], 1)[0]):
            df_cities_activities_spots.loc[len(df_cities_activities_spots)] = [
                city,
                province,
                activity,
                random.sample(activities_dict[activity], random.sample(list(range(2, 10)), 1)[0])
            ]

# %%
df_cities_activities_spots.to_csv("../data/cities_activities_spots.csv", index=0)

# %%
s = ""
for k in activities_dict.keys():
    print(k)
# Out:
# Swimming
# River Rafting
# Cherry Blossom Viewing
# Picnic
# Beach
# Rock Climbing
# Hiking/Trekking
# Camping
# Cycling
# Boating
# Skiing/Snowboarding
# Fishing
# Horse-riding
# Canoeing
# Mountaineering
# Photography

# %%
print(s)
# Out:
# Swimming River Rafting Cherry Blossom Viewing Picnic Beach Rock Climbing Hiking/Trekking Camping Cycling Boating Skiing/Snowboarding Fishing Horse-riding Canoeing Mountaineering Photography

# %%
data_path = "../data/items_data.csv"
data_path_mod = "../data/items_data_utf.csv"

# %%
with open(data_path, "rb") as f:
    lines = [l.decode('utf8', 'ignore') for l in f.readlines()]

with open(data_path_mod, "w") as f:
    for line in lines:
        f.write(line)

# %%
df_items_list = pd.read_csv(data_path_mod, na_filter=False)
df_items_list.drop(index=0, inplace=True)

# %%
df_items_list
# Out:
#                      Swimming      River Rafting  \
# 1    CLOTHING AND ACCESSORIES  Travel Essentials
# 2       Swimsuit and Cover-up              Tents
# 3                   Hair ties      Sleeping bags
# 4                         Hat      Sleeping pads
# 5                       Shoes            Pillows
# ..                        ...                ...
# 123
# 124
# 125
# 126
# 127
#
#                           Cherry Blossom Viewing  \
# 1                                     Essentials
# 2                     A warm jacket or outerwear
# 3                             A large picnic mat
# 4                                    An umbrella
# 5    Disposable utensils, cutlery & garbage bags
# ..                                           ...
# 123
# 124
# 125
# 126
# 127
#
#                                                 Picnic  \
# 1                              For Toting and Seating:
# 2
# 3                          Picnic basket or canvas bag
# ...

# %%
import numpy as np

# %%
from collections import defaultdict

activities_items_dict = defaultdict(lambda: defaultdict(list))

for column in df_items_list.columns:
    lis = list(df_items_list[column])
    i = 1
    category = lis[0]
    while i < len(lis) - 1:
        if lis[i] == "" and lis[i+1] == "":
            break
        if lis[i] == "":
            category = lis[i+1]
            item_list = list()
            i += 2
        activities_items_dict[column][category].append(lis[i])
        i += 1

# %%
df_activities_items = pd.DataFrame(columns=["activity", "category", "item"])

for activity, item_dict in activities_items_dict.items():
    for item_category, items in item_dict.items():
        df_activities_items.loc[len(df_activities_items)] = [activity, item_category.strip().lower(), [item.strip(" *").lower() for item in items]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4912\2604758059.py in <cell line: 3>()
#       3 for activity, item_dict in activities_items_dict.items():
#       4     for item_category, item in item_dict.items():
# ----> 5         df_activities_items.loc[len(df_activities_items)] = [activity, item_category.lower(), item.lower()]
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
df_activities_items.to_csv("../data/activities_items.csv", index=0)
